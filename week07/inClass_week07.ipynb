# %% [markdown]
# # In Class Notebook, Week 07

# %% [markdown]
# You can always find here: https://github.com/UIUC-iSchool-DataViz/is445_oauoag_spring2023/blob/master/week07/inClass_week07.ipynb
#
# Or into the nbviewer interface for a plain-text rendering:
#
# https://kokes.github.io/nbviewer.js/viewer.html

# %%
import bqplot
import geopandas
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## A quick few mapping things with bqplot

# %%
# 1. data/"axis"
shape_data = bqplot.topo_load('map_data/WorldMap.json')

# 2. scales
sc_geo = bqplot.Mercator()

# 3. marks
shape_map = bqplot.Map(map_data=shape_data, 
                      scales={'projection':sc_geo})

# put it all together as a figure
fig = bqplot.Figure(marks=[shape_map],
                   fig_margin={'top':0, 'bottom':0, 'left':0, 'right':0})
fig
# Out:
# Figure(fig_margin={'top': 0, 'bottom': 0, 'left': 0, 'right': 0}, marks=[Map(hovered_styles={'hovered_fill': '…

# %%
# 1. data/"axis"
shape_data = bqplot.topo_load('map_data/USStatesMap.json')

# 2. scales
#sc_geo = bqplot.Mercator()
sc_geo = bqplot.AlbersUSA()

# 3. marks
shape_map = bqplot.Map(map_data=shape_data, 
                      scales={'projection':sc_geo})

# put it all together as a figure
fig = bqplot.Figure(marks=[shape_map],
                   fig_margin={'top':0, 'bottom':0, 'left':0, 'right':0})
fig
# Out:
# Figure(fig_margin={'top': 0, 'bottom': 0, 'left': 0, 'right': 0}, marks=[Map(hovered_styles={'hovered_fill': '…

# %%
# !ls /Users/jnaiman/opt/anaconda3/pkgs/bqplot-0.12.30-pyhd8ed1ab_0/site-packages/bqplot/map_data/
# Out:
# EuropeMap.json     USCountiesMap.json USStatesMap.json   WorldMap.json

# %% [markdown]
# ## Geopandas

# %%
geopandas.datasets.available
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %%
gdf = geopandas.read_file(geopandas.datasets.get_path('nybb'))
ax = gdf.plot(figsize=(3,3), edgecolor='k', alpha=0.5)

# %%
councils = geopandas.read_file('https://gisportal.champaignil.gov/ms/rest/services/Open_Data/Open_Data/MapServer/1/query?outFields=*&where=1%3D1&f=geojson')

# %%
councils.head()
# Out:
#    OBJECTID_1 District        Council_me  Shape.STArea()  Shape.STLength()  \
# 0         811        5   Vanna Pianfetti    1.843311e+08     209994.935616
# 1         812        3    Daniel Iniguez    2.009197e+08     144362.359386
# 2         813        1   Davion Williams    1.079102e+08      83420.370461
# 3         814        4  Michael Foellmer    1.049800e+08      77363.320814
# 4         815        2       Alicia Beck    5.289209e+07      58843.335293
#
#                                             geometry
# 0  POLYGON ((-88.31441 40.11699, -88.31454 40.116...
# 1  POLYGON ((-88.27716 40.16364, -88.27732 40.163...
# 2  POLYGON ((-88.22283 40.16000, -88.22283 40.160...
# 3  POLYGON ((-88.26890 40.12733, -88.27076 40.127...
# 4  POLYGON ((-88.23537 40.10798, -88.23537 40.107...

# %%
councils.describe()
# Out:
#        OBJECTID_1  Shape.STArea()  Shape.STLength()
# count    5.000000    5.000000e+00          5.000000
# mean   813.000000    1.302066e+08     114796.864314
# std      1.581139    6.132057e+07      62155.738339
# min    811.000000    5.289209e+07      58843.335293
# 25%    812.000000    1.049800e+08      77363.320814
# 50%    813.000000    1.079102e+08      83420.370461
# 75%    814.000000    1.843311e+08     144362.359386
# max    815.000000    2.009197e+08     209994.935616

# %%
councils.plot()

# %%
fig, ax = plt.subplots(figsize=(3,3))
councils.plot(ax=ax)
plt.show()

# %%
councils.boundary.plot()

# %%
councils.bounds
# Out:
#         minx       miny       maxx       maxy
# 0 -88.333303  40.061894 -88.257012  40.116995
# 1 -88.315071  40.098268 -88.239120  40.163956
# 2 -88.277158  40.107938 -88.221225  40.163721
# 3 -88.276971  40.083257 -88.240119  40.127432
# 4 -88.257818  40.083182 -88.228485  40.116346

# %%
councils.centroid
# Out:
# /Users/jnaiman/opt/anaconda3/envs/DataViz/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   """Entry point for launching an IPython kernel.
# 0    POINT (-88.29990 40.08716)
# 1    POINT (-88.28230 40.13391)
# 2    POINT (-88.24309 40.13570)
# 3    POINT (-88.25983 40.10719)
# 4    POINT (-88.24077 40.10002)
# dtype: geometry

# %%
councils.crs # CRS = Coordinate Reference System
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
props = geopandas.read_file('https://gisportal.champaignil.gov/ms/rest/services/Open_Data/Open_Data/MapServer/2/query?outFields=*&where=1%3D1&f=geojson')

# %%
props.head()
# Out:
#    OBJECTID COMMENTS    CB DEPT           PIN ACREAGE CODE_TYPE  \
# 0         1                 PWD  412001326010  0.755*         A
# 1         2           None  NSD  422012226003  4.432*         D
# 2         3           None  NSD  422012226004  0.181*         D
# 3         4           None  NSD  422012226005  0.186*         D
# 4         5           None  NSD  422012226006  0.185*         D
#
#           DESCRIPTION                 TYPE DEPT_ABBR      DESCRIP_ADDR  \
# 0   Drainage/Boneyard     Boneyard Channel       PWD  Boneyard Channel
# 1  City Redevelopment  Beardsley Park Plan       NSD       1110 N Neil
# 2  City Redevelopment  Beardsley Park Plan       NSD       1110 N Neil
# 3  City Redevelopment  Beardsley Park Plan       NSD       1108 N Neil
# 4  City Redevelopment  Beardsley Park Plan       NSD       1106 N Neil
#
#               FUTURE     PA ZONING  Shape.STArea()  Shape.STLength()  \
# 0  Flood Hazard Area  101.0    MHP    32930.497936        897.925620
# ...

# %%
fig, ax = plt.subplots(figsize=(3,3))
councils.plot(ax=ax)
props.plot(ax=ax, color='lightgreen')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3,3))
councils.plot(ax=ax)
props.plot(ax=ax, color='lightgreen')
ax.set_xlim(-88.245,-88.225)
ax.set_ylim(40.10,40.125)
plt.show()

# %% [markdown]
# ## geopandas + contextily

# %%
gdf = geopandas.read_file(geopandas.datasets.get_path('nybb'))

# %%
gdf
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         4         Queens  896344.047763  3.045213e+09
# 2         3       Brooklyn  741080.523166  1.937479e+09
# 3         1      Manhattan  359299.096471  6.364715e+08
# 4         2          Bronx  464392.991824  1.186925e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 3  MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4  MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %%
gdf.plot()

# %%
gdf.crs
# Out:
# <Projected CRS: EPSG:2263>
# Name: NAD83 / New York Long Island (ftUS)
# Axis Info [cartesian]:
# - X[east]: Easting (US survey foot)
# - Y[north]: Northing (US survey foot)
# Area of Use:
# - name: United States (USA) - New York - counties of Bronx; Kings; Nassau; New York; Queens; Richmond; Suffolk.
# - bounds: (-74.26, 40.47, -71.8, 41.3)
# Coordinate Operation:
# - name: SPCS83 New York Long Island zone (US Survey feet)
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
gdf = gdf.to_crs(epsg = 4326)

# %%
gdf.plot()

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
import contextily as ctx

# %%
gdf = gdf.to_crs(epsg=3857)

# %%
gdf.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(3,3))
gdf.plot(ax=ax, alpha=0.5, edgecolor='k')
ctx.add_basemap(ax=ax)
plt.show()

# %%
councils
# Out:
#    OBJECTID_1 District        Council_me  Shape.STArea()  Shape.STLength()  \
# 0         811        5   Vanna Pianfetti    1.843311e+08     209994.935616
# 1         812        3    Daniel Iniguez    2.009197e+08     144362.359386
# 2         813        1   Davion Williams    1.079102e+08      83420.370461
# 3         814        4  Michael Foellmer    1.049800e+08      77363.320814
# 4         815        2       Alicia Beck    5.289209e+07      58843.335293
#
#                                             geometry
# 0  POLYGON ((-88.31441 40.11699, -88.31454 40.116...
# 1  POLYGON ((-88.27716 40.16364, -88.27732 40.163...
# 2  POLYGON ((-88.22283 40.16000, -88.22283 40.160...
# 3  POLYGON ((-88.26890 40.12733, -88.27076 40.127...
# 4  POLYGON ((-88.23537 40.10798, -88.23537 40.107...

# %%
councils.plot()

# %%
councils.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
councils = councils.to_crs(epsg=3857)

# %%
councils.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(3,3))
councils.plot(ax=ax, alpha=0.5, edgecolor='k')
ctx.add_basemap(ax=ax)
plt.show()

# %%
councils = councils.to_crs(epsg=4326)

# %%
councils.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(3,3))
councils.plot(ax=ax, alpha=0.5, edgecolor='k')
ctx.add_basemap(ax=ax, crs=councils.crs)
#ctx.add_basemap(ax=ax, crs=councils.crs.to_string())
plt.show()

# %%
apts = geopandas.read_file('https://gisportal.champaignil.gov/ms/rest/services/Open_Data/Open_Data/MapServer/8/query?outFields=*&where=1%3D1&f=geojson')

# %%
apts.head()
# Out:
#    OBJECTID             Address        Parcel Units Stories  UniqueID  \
# 0         1  2009 Moreland Blvd  412001126038    36       3       0.0
# 1         2  2011 Moreland Blvd  412001126038    36      3        1.0
# 2         3  2007 Moreland Blvd  412001126038    24       3       2.0
# 3         4  2003 Moreland Blvd  412001126038    36       3       3.0
# 4         5  2005 Moreland Blvd  412001126038    24       3       4.0
#
#         Building_Name                     Complex_Name Case_Number  \
# 0  2009 Moreland Blvd  University Village at Champaign   AI07-0147
# 1  2011 Moreland Blvd  University Village at Champaign   AI07-0147
# 2  2007 Moreland Blvd  University Village at Champaign   AI07-0147
# 3  2003 Moreland Blvd  University Village at Champaign   AI07-0147
# 4  2005 Moreland Blvd  University Village at Champaign   AI07-0147
#
#   Building_Type  ...     Last_Date  Comments Safety_Comments Fire_Alarms  \
# ...

# %%
apts['Building_Type'].unique()
# Out:
# array(['Complex', 'Building', 'House', 'Over Commercial'], dtype=object)

# %%
fig, ax = plt.subplots(figsize=(3,3))
councils.plot(ax=ax, alpha=0.5, edgecolor='k')
apts.plot(ax=ax,color='lightgreen')

ctx.add_basemap(ax=ax, crs=councils.crs)

ax.set_xlim(-88.245, -88.225)
ax.set_ylim(40.10, 40.125)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3,3))
councils.plot(ax=ax, alpha=0.5, edgecolor='k')
apts.plot(ax=ax,color='lightgreen')

ax.set_xlim(-88.245, -88.225)
ax.set_ylim(40.10, 40.125)

ctx.add_basemap(ax=ax, crs=councils.crs)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,5))
councils.plot(ax=ax, alpha=0.5, edgecolor='k')
apts.plot(column = 'Building_Type', ax=ax, cmap='rainbow')

ax.set_xlim(-88.245, -88.225)
ax.set_ylim(40.10, 40.125)

ctx.add_basemap(ax=ax, crs=councils.crs)
plt.show()
